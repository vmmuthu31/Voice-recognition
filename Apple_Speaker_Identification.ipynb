# %%
# !pip install speaker-verification-toolkit

# %%
# !pip install numba==0.48
# Out:
# Collecting numba==0.48
#   Downloading numba-0.48.0-1-cp38-cp38-manylinux2014_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 5.7 MB/s eta 0:00:01     |████▏                           | 460 kB 5.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.8/dist-packages (from numba==0.48) (1.22.0)
# Collecting llvmlite<0.32.0,>=0.31.0dev0
#   Downloading llvmlite-0.31.0-cp38-cp38-manylinux1_x86_64.whl (20.2 MB)
#      |████████████████████████████████| 20.2 MB 3.6 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba==0.48) (45.2.0)
# Installing collected packages: llvmlite, numba
# Successfully installed llvmlite-0.31.0 numba-0.48.0

# %%
import speaker_verification_toolkit.tools as svt

# %%
import librosa

# %%
librosa.load('/content/Shobha.wav')
# Out:
# (array([-6.6978714e-07,  8.1520119e-07, -9.6907604e-07, ...,
#          3.8325019e-02,  3.4522779e-02,  3.6402646e-02], dtype=float32), 22050)

# %%
data1, sr = librosa.load('/content/Shonbha_2.wav', sr=16000, mono=True)
data2, sr = librosa.load('/content/Shobha.wav', sr=16000, mono=True)

data1 = svt.rms_silence_filter(data1)
data2 = svt.rms_silence_filter(data2)

data1 = svt.extract_mfcc(data1)
data2 = svt.extract_mfcc(data2)

print(
    'The difference between voice1 and voice2 is',
    svt.compute_distance(data1,data2)
)
# Out:
# The difference between voice1 and voice2 is 136760.3550290822

# %%
data3, sr = librosa.load('/content/example.wav', sr=16000, mono=True)
data3 = svt.rms_silence_filter(data3)
data3 = svt.extract_mfcc(data3)

# %%
svt.compute_distance(data3, data2)
# Out:
# 1013011.269559927

# %%
svt.find_nearest_voice_data([ data3, data1], data2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29409/4205123579.py in <module>
# ----> 1 svt.find_nearest_voice_data([ data3, data1], data2)
#
# NameError: name 'svt' is not defined
